# %%
import pandas as pd

urls = ["https://stats.bis.org/api/v2/data/dataflow/BIS/WS_EER/1.0/?format=csv"]

df = pd.concat([pd.read_csv(url) for url in urls])
df
# Out:
#         FREQ EER_TYPE EER_BASKET REF_AREA  UNIT_MEASURE  TIME_FORMAT  \
# 0          M        N          N       CH           882          NaN
# 1          M        N          N       CH           882          NaN
# 2          M        N          N       CH           882          NaN
# 3          M        N          N       CH           882          NaN
# 4          M        N          N       CH           882          NaN
# ...      ...      ...        ...      ...           ...          ...
# 1168786    D        N          B       SG           882          NaN
# 1168787    D        N          B       SG           882          NaN
# 1168788    D        N          B       SG           882          NaN
# 1168789    D        N          B       SG           882          NaN
# 1168790    D        N          B       SG           882          NaN
#
#         COLLECTION                                       TITLE_TS TIME_PERIOD  \
# ...

# %%
#FREQ only keep D
#create 2 dataframes one for EER_TYPE N one for R
