# %%
import fitz  # PyMuPDF
import pandas as pd
import re
import os

# Path to the Latin America PDF file
pdf_path = r"C:\Users\clint\Desktop\RER\data\Remittance_3\Remitscope_LatAm_central_bank.pdf"

# Check if file exists
if os.path.exists(pdf_path):
    print(f"PDF found: {pdf_path}")
else:
    print(f"PDF not found at: {pdf_path}")
    print("Please check the file path.")
# Out:
# PDF found: C:\Users\clint\Desktop\RER\data\Remittance_3\Remitscope_LatAm_central_bank.pdf

# %%
import camelot
import pandas as pd
import re

# Try to extract tables using Camelot from pages 1-7
try:
    # Extract tables from first seven pages
    tables = camelot.read_pdf(pdf_path, pages='1-7', flavor='stream')
    print(f"Number of tables found: {len(tables)}")
    
    if len(tables) > 0:
        for i, table in enumerate(tables):
            print(f"\nTable {i+1}:")
            print(f"Shape: {table.df.shape}")
            print(table.df.head(10))
            print("="*50)
    else:
        print("No tables found with Camelot")
        
except Exception as e:
    print(f"Error with Camelot: {e}")
    print("Let's try manual parsing...")
# Out:
# Number of tables found: 7
#
# Table 1:
# Shape: (90, 6)
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  Date
# 2                                        Afghanistan           Ecuador  2021
# 3                                                               Mexico  2022
# 4                                                               Panama  2022
# 5                                            Albania           Ecuador  2021
# 6                                                               Mexico  2022
# 7                                                               Panama  2022
# 8                                    American\tSamoa           Ecuador  2021
# 9                                             Angola            Brazil  2022
#
#              3              4                    5
# 0
# 1        Value           Unit               Source
# 2   0.03859066  USD\tmillions  Central\tBank\tData
# 3     0.295915  USD\tmillions  Central\tBank\tData
# 4  0.000387472  USD\tmillions                 INEC
# 5   1.89796382  USD\tmillions  Central\tBank\tData
# 6     0.023831  USD\tmillions  Central\tBank\tData
# 7  0.038935399  USD\tmillions                 INEC
# 8    0.0553291  USD\tmillions  Central\tBank\tData
# 9   8.32422068  USD\tmillions  Central\tBank\tData
# ==================================================
#
# Table 2:
# Shape: (92, 6)
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                           British\tVirgin\tIslands            Mexico  2022
# 3                                                               Panama  2022
# 4                                 Brunei\tDarussalam           Ecuador  2021
# 5                                           Bulgaria           Ecuador  2021
# 6                                                               Mexico  2022
# 7                                                               Panama  2022
# 8                                      Burkina\tFaso           Ecuador  2021
# 9                                                               Mexico  2022
#
#              3              4                    5
# 0
# 1  7.559672433  USD\tmillions               Source
# 2     0.007236  USD\tmillions  Central\tBank\tData
# 3  0.064766636  USD\tmillions                 INEC
# 4   0.00104482  USD\tmillions  Central\tBank\tData
# 5   0.09197525  USD\tmillions  Central\tBank\tData
# 6     0.031933  USD\tmillions  Central\tBank\tData
# 7  0.010352968  USD\tmillions                 INEC
# 8   0.02703836  USD\tmillions  Central\tBank\tData
# 9     0.098277  USD\tmillions  Central\tBank\tData
# ==================================================
#
# Table 3:
# Shape: (91, 6)
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                      Democratic\tRepublic\tof\tthe
# 2                                   Sending\tcountry  Receive\tcountry  2022
# 3                                            Denmark           Ecuador  2021
# 4                                                               Mexico  2022
# 5                                                               Panama  2022
# 6                                           Djibouti            Mexico  2022
# 7                                           Dominica           Ecuador  2021
# 8                                                               Mexico  2022
# 9                                                               Panama  2022
#
#              3              4                    5
# 0
# 1
# 2     0.377893  USD\tmillions               Source
# 3   1.15053584  USD\tmillions  Central\tBank\tData
# 4      0.31848  USD\tmillions  Central\tBank\tData
# 5  0.230669853  USD\tmillions                 INEC
# 6     0.000503  USD\tmillions  Central\tBank\tData
# 7   0.01993682  USD\tmillions  Central\tBank\tData
# 8     0.011373  USD\tmillions  Central\tBank\tData
# 9  0.096307644  USD\tmillions                 INEC
# ==================================================
#
# Table 4:
# Shape: (91, 6)
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry     Receive\tcountry
# 2                                              Haiti          Costa\tRica
# 3                                                     Dominican\tRepublic
# 4                                                                 Ecuador
# 5                                                                  Mexico
# 6                                                                  Panama
# 7                                                                Suriname
# 8                                           Honduras             Colombia
# 9                                                                 Ecuador
#
#       2              3              4                    5
# 0
# 1  2022    1.047403962  USD\tmillions               Source
# 2  2022  117.596426417  USD\tmillions  Central\tBank\tData
# 3  2022  117.596426417  USD\tmillions  Central\tBank\tData
# 4  2021     1.37301048  USD\tmillions  Central\tBank\tData
# 5  2022       0.703677  USD\tmillions  Central\tBank\tData
# 6  2022    4.335585707  USD\tmillions                 INEC
# 7  2022    1.158916678  USD\tmillions  Central\tBank\tData
# 8  2022    9.764404582  USD\tmillions  Central\tBank\tData
# 9  2021     2.20795527  USD\tmillions  Central\tBank\tData
# ==================================================
#
# Table 5:
# Shape: (90, 6)
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                                  Marshall\tIslands           Ecuador  2021
# 3                                                               Mexico  2022
# 4                                         Martinique           Ecuador  2021
# 5                                                                Haiti  2019
# 6                                                               Mexico  2022
# 7                                         Mauritania           Ecuador  2021
# 8                                          Mauritius           Ecuador  2021
# 9                                                               Mexico  2022
#
#               3              4                    5
# 0
# 1   0.068784969  USD\tmillions               Source
# 2    0.03065554  USD\tmillions  Central\tBank\tData
# 3      0.001662  USD\tmillions  Central\tBank\tData
# 4    0.00524036  USD\tmillions  Central\tBank\tData
# 5  39.439517940  USD\tmillions  Central\tBank\tData
# 6      0.022782  USD\tmillions  Central\tBank\tData
# 7     7.908e-05  USD\tmillions  Central\tBank\tData
# 8    0.00981925  USD\tmillions  Central\tBank\tData
# 9       0.00019  USD\tmillions  Central\tBank\tData
# ==================================================
#
# Table 6:
# Shape: (91, 6)
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                                Republic\tof\tKorea            Panama  2022
# 3                              Republic\tof\tMoldova           Ecuador  2021
# 4                                                               Mexico  2022
# 5                                            Réunion            Mexico  2022
# 6                                            Romania           Ecuador  2021
# 7                                                               Mexico  2022
# 8                                                               Panama  2022
# 9                                Russian\tFederation           Ecuador  2021
#
#              3              4                    5
# 0
# 1     0.188341  USD\tmillions               Source
# 2  0.418495932  USD\tmillions                 INEC
# 3   0.11212232  USD\tmillions  Central\tBank\tData
# 4     0.003839  USD\tmillions  Central\tBank\tData
# 5     0.000868  USD\tmillions  Central\tBank\tData
# 6   0.31755202  USD\tmillions  Central\tBank\tData
# 7     0.141631  USD\tmillions  Central\tBank\tData
# 8  0.079066158  USD\tmillions                 INEC
# 9   6.59514737  USD\tmillions  Central\tBank\tData
# ==================================================
#
# Table 7:
# Shape: (76, 6)
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2021
# 2                                         Tajikistan            Mexico  2022
# 3                                           Thailand           Ecuador  2021
# 4                                                               Mexico  2022
# 5                                                               Panama  2022
# 6                                        Timor-Leste            Mexico  2022
# 7                                               Togo           Ecuador  2021
# 8                                                               Mexico  2022
# 9                              Trinidad\tand\tTobago          Colombia  2022
#
#              3              4                    5
# 0
# 1       0.0488  USD\tmillions               Source
# 2      0.00556  USD\tmillions  Central\tBank\tData
# 3   0.15738123  USD\tmillions  Central\tBank\tData
# 4      0.08895  USD\tmillions  Central\tBank\tData
# 5  0.067822704  USD\tmillions                 INEC
# 6      0.00016  USD\tmillions  Central\tBank\tData
# 7   0.02248343  USD\tmillions  Central\tBank\tData
# 8     0.039602  USD\tmillions  Central\tBank\tData
# 9  0.589172170  USD\tmillions  Central\tBank\tData
# ==================================================

# %%
# Test both lattice and stream approaches for LatAm PDF
import os

# Create output directory for LatAm data if it doesn't exist
output_dir = r"C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm"
os.makedirs(output_dir, exist_ok=True)

print("Testing both Camelot approaches for LatAm PDF: lattice and stream")
print("="*60)

# Approach 1: Stream flavor (better for tables without clear borders)
print("\n1. TESTING STREAM FLAVOR (Pages 1-7)")
print("-" * 30)
try:
    tables_stream = camelot.read_pdf(pdf_path, pages='1-7', flavor='stream')
    print(f"Stream - Number of tables found: {len(tables_stream)}")
    
    if len(tables_stream) > 0:
        for i, table in enumerate(tables_stream):
            print(f"\nStream Table {i+1}:")
            print(f"Shape: {table.df.shape}")
            print(f"Accuracy: {table.accuracy:.2f}")
            print("Preview (first 5 rows):")
            print(table.df.head())
            
            # Save to CSV
            csv_filename = f"latam_stream_table_{i+1}.csv"
            csv_path = os.path.join(output_dir, csv_filename)
            table.df.to_csv(csv_path, index=False)
            print(f"Saved to: {csv_path}")
            print("-" * 40)
    else:
        print("No tables found with stream flavor")
        
except Exception as e:
    print(f"Error with stream flavor: {e}")

print("\n" + "="*60)

# Approach 2: Lattice flavor (better for tables with clear borders)
print("\n2. TESTING LATTICE FLAVOR (Pages 1-7)")
print("-" * 30)
try:
    tables_lattice = camelot.read_pdf(pdf_path, pages='1-7', flavor='lattice')
    print(f"Lattice - Number of tables found: {len(tables_lattice)}")
    
    if len(tables_lattice) > 0:
        for i, table in enumerate(tables_lattice):
            print(f"\nLattice Table {i+1}:")
            print(f"Shape: {table.df.shape}")
            print(f"Accuracy: {table.accuracy:.2f}")
            print("Preview (first 5 rows):")
            print(table.df.head())
            
            # Save to CSV
            csv_filename = f"latam_lattice_table_{i+1}.csv"
            csv_path = os.path.join(output_dir, csv_filename)
            table.df.to_csv(csv_path, index=False)
            print(f"Saved to: {csv_path}")
            print("-" * 40)
    else:
        print("No tables found with lattice flavor")
        
except Exception as e:
    print(f"Error with lattice flavor: {e}")

print("\n" + "="*60)
print("SUMMARY:")
print(f"Output directory: {output_dir}")
print("Check the CSV files to compare the results from both approaches.")
# Out:
# Testing both Camelot approaches for LatAm PDF: lattice and stream
# ============================================================
#
# 1. TESTING STREAM FLAVOR (Pages 1-7)
# ------------------------------
# Stream - Number of tables found: 7
#
# Stream Table 1:
# Shape: (90, 6)
# Accuracy: 99.90
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  Date
# 2                                        Afghanistan           Ecuador  2021
# 3                                                               Mexico  2022
# 4                                                               Panama  2022
#
#              3              4                    5
# 0
# 1        Value           Unit               Source
# 2   0.03859066  USD\tmillions  Central\tBank\tData
# 3     0.295915  USD\tmillions  Central\tBank\tData
# 4  0.000387472  USD\tmillions                 INEC
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_1.csv
# ----------------------------------------
#
# Stream Table 2:
# Shape: (92, 6)
# Accuracy: 99.91
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                           British\tVirgin\tIslands            Mexico  2022
# 3                                                               Panama  2022
# 4                                 Brunei\tDarussalam           Ecuador  2021
#
#              3              4                    5
# 0
# 1  7.559672433  USD\tmillions               Source
# 2     0.007236  USD\tmillions  Central\tBank\tData
# 3  0.064766636  USD\tmillions                 INEC
# 4   0.00104482  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_2.csv
# ----------------------------------------
#
# Stream Table 3:
# Shape: (91, 6)
# Accuracy: 99.91
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                      Democratic\tRepublic\tof\tthe
# 2                                   Sending\tcountry  Receive\tcountry  2022
# 3                                            Denmark           Ecuador  2021
# 4                                                               Mexico  2022
#
#             3              4                    5
# 0
# 1
# 2    0.377893  USD\tmillions               Source
# 3  1.15053584  USD\tmillions  Central\tBank\tData
# 4     0.31848  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_3.csv
# ----------------------------------------
#
# Stream Table 4:
# Shape: (91, 6)
# Accuracy: 99.90
# Preview (first 5 rows):
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry     Receive\tcountry
# 2                                              Haiti          Costa\tRica
# 3                                                     Dominican\tRepublic
# 4                                                                 Ecuador
#
#       2              3              4                    5
# 0
# 1  2022    1.047403962  USD\tmillions               Source
# 2  2022  117.596426417  USD\tmillions  Central\tBank\tData
# 3  2022  117.596426417  USD\tmillions  Central\tBank\tData
# 4  2021     1.37301048  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_4.csv
# ----------------------------------------
#
# Stream Table 5:
# Shape: (90, 6)
# Accuracy: 99.91
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                                  Marshall\tIslands           Ecuador  2021
# 3                                                               Mexico  2022
# 4                                         Martinique           Ecuador  2021
#
#              3              4                    5
# 0
# 1  0.068784969  USD\tmillions               Source
# 2   0.03065554  USD\tmillions  Central\tBank\tData
# 3     0.001662  USD\tmillions  Central\tBank\tData
# 4   0.00524036  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_5.csv
# ----------------------------------------
#
# Stream Table 6:
# Shape: (91, 6)
# Accuracy: 99.90
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                                Republic\tof\tKorea            Panama  2022
# 3                              Republic\tof\tMoldova           Ecuador  2021
# 4                                                               Mexico  2022
#
#              3              4                    5
# 0
# 1     0.188341  USD\tmillions               Source
# 2  0.418495932  USD\tmillions                 INEC
# 3   0.11212232  USD\tmillions  Central\tBank\tData
# 4     0.003839  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_6.csv
# ----------------------------------------
#
# Stream Table 7:
# Shape: (76, 6)
# Accuracy: 99.89
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2021
# 2                                         Tajikistan            Mexico  2022
# 3                                           Thailand           Ecuador  2021
# 4                                                               Mexico  2022
#
#             3              4                    5
# 0
# 1      0.0488  USD\tmillions               Source
# 2     0.00556  USD\tmillions  Central\tBank\tData
# 3  0.15738123  USD\tmillions  Central\tBank\tData
# 4     0.08895  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_7.csv
# ----------------------------------------
#
# ============================================================
#
# 2. TESTING LATTICE FLAVOR (Pages 1-7)
# ------------------------------
# Stream - Number of tables found: 7
#
# Stream Table 1:
# Shape: (90, 6)
# Accuracy: 99.90
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  Date
# 2                                        Afghanistan           Ecuador  2021
# 3                                                               Mexico  2022
# 4                                                               Panama  2022
#
#              3              4                    5
# 0
# 1        Value           Unit               Source
# 2   0.03859066  USD\tmillions  Central\tBank\tData
# 3     0.295915  USD\tmillions  Central\tBank\tData
# 4  0.000387472  USD\tmillions                 INEC
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_1.csv
# ----------------------------------------
#
# Stream Table 2:
# Shape: (92, 6)
# Accuracy: 99.91
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                           British\tVirgin\tIslands            Mexico  2022
# 3                                                               Panama  2022
# 4                                 Brunei\tDarussalam           Ecuador  2021
#
#              3              4                    5
# 0
# 1  7.559672433  USD\tmillions               Source
# 2     0.007236  USD\tmillions  Central\tBank\tData
# 3  0.064766636  USD\tmillions                 INEC
# 4   0.00104482  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_2.csv
# ----------------------------------------
#
# Stream Table 3:
# Shape: (91, 6)
# Accuracy: 99.91
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                      Democratic\tRepublic\tof\tthe
# 2                                   Sending\tcountry  Receive\tcountry  2022
# 3                                            Denmark           Ecuador  2021
# 4                                                               Mexico  2022
#
#             3              4                    5
# 0
# 1
# 2    0.377893  USD\tmillions               Source
# 3  1.15053584  USD\tmillions  Central\tBank\tData
# 4     0.31848  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_3.csv
# ----------------------------------------
#
# Stream Table 4:
# Shape: (91, 6)
# Accuracy: 99.90
# Preview (first 5 rows):
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry     Receive\tcountry
# 2                                              Haiti          Costa\tRica
# 3                                                     Dominican\tRepublic
# 4                                                                 Ecuador
#
#       2              3              4                    5
# 0
# 1  2022    1.047403962  USD\tmillions               Source
# 2  2022  117.596426417  USD\tmillions  Central\tBank\tData
# 3  2022  117.596426417  USD\tmillions  Central\tBank\tData
# 4  2021     1.37301048  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_4.csv
# ----------------------------------------
#
# Stream Table 5:
# Shape: (90, 6)
# Accuracy: 99.91
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                                  Marshall\tIslands           Ecuador  2021
# 3                                                               Mexico  2022
# 4                                         Martinique           Ecuador  2021
#
#              3              4                    5
# 0
# 1  0.068784969  USD\tmillions               Source
# 2   0.03065554  USD\tmillions  Central\tBank\tData
# 3     0.001662  USD\tmillions  Central\tBank\tData
# 4   0.00524036  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_5.csv
# ----------------------------------------
#
# Stream Table 6:
# Shape: (91, 6)
# Accuracy: 99.90
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2022
# 2                                Republic\tof\tKorea            Panama  2022
# 3                              Republic\tof\tMoldova           Ecuador  2021
# 4                                                               Mexico  2022
#
#              3              4                    5
# 0
# 1     0.188341  USD\tmillions               Source
# 2  0.418495932  USD\tmillions                 INEC
# 3   0.11212232  USD\tmillions  Central\tBank\tData
# 4     0.003839  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_6.csv
# ----------------------------------------
#
# Stream Table 7:
# Shape: (76, 6)
# Accuracy: 99.89
# Preview (first 5 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcountry  2021
# 2                                         Tajikistan            Mexico  2022
# 3                                           Thailand           Ecuador  2021
# 4                                                               Mexico  2022
#
#             3              4                    5
# 0
# 1      0.0488  USD\tmillions               Source
# 2     0.00556  USD\tmillions  Central\tBank\tData
# 3  0.15738123  USD\tmillions  Central\tBank\tData
# 4     0.08895  USD\tmillions  Central\tBank\tData
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_7.csv
# ----------------------------------------
#
# ============================================================
#
# 2. TESTING LATTICE FLAVOR (Pages 1-7)
# ------------------------------
# Lattice - Number of tables found: 0
# No tables found with lattice flavor
#
# ============================================================
# SUMMARY:
# Output directory: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm
# Check the CSV files to compare the results from both approaches.
# Lattice - Number of tables found: 0
# No tables found with lattice flavor
#
# ============================================================
# SUMMARY:
# Output directory: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm
# Check the CSV files to compare the results from both approaches.

# %%
# Load and clean the extracted LatAm data
print("ANALYZING EXTRACTED LATAM DATA")
print("="*50)

# Check for all extracted files in the LatAm directory
import glob

stream_files = glob.glob(os.path.join(output_dir, "latam_stream_table_*.csv"))
lattice_files = glob.glob(os.path.join(output_dir, "latam_lattice_table_*.csv"))

print(f"Found {len(stream_files)} stream tables and {len(lattice_files)} lattice tables")

# Function to clean the dataframes
def clean_latam_remittance_data(df):
    """Clean the extracted LatAm remittance data"""
    clean_df = df.copy()
    
    # Find where the actual data starts (after header rows)
    data_start = 0
    for i, row in clean_df.iterrows():
        # Look for common indicators of data start in remittance tables
        row_str = ' '.join([str(cell) for cell in row if pd.notna(cell)])
        if any(keyword in row_str.lower() for keyword in ['sending', 'country', 'recipient', 'remittance', 'million']):
            # Check if this looks like a header row
            if any(header in row_str.lower() for header in ['sending country', 'recipient country', 'remittances']):
                data_start = i + 1
                break
    
    if data_start > 0:
        clean_df = clean_df.iloc[data_start:].reset_index(drop=True)
    
    # Remove empty rows
    clean_df = clean_df.dropna(how='all').reset_index(drop=True)
    
    # Remove rows that are mostly empty (less than 2 non-null values)
    clean_df = clean_df[clean_df.count(axis=1) >= 2].reset_index(drop=True)
    
    return clean_df

# Process stream files
for i, file_path in enumerate(stream_files):
    print(f"\nProcessing Stream Table {i+1}:")
    df = pd.read_csv(file_path)
    print(f"Raw shape: {df.shape}")
    print("Raw data preview:")
    print(df.head())
    
    # Clean the data
    clean_df = clean_latam_remittance_data(df)
    print(f"\nCleaned shape: {clean_df.shape}")
    print("Cleaned data preview:")
    print(clean_df.head())
    
    # Save cleaned data
    clean_filename = f"latam_stream_table_{i+1}_cleaned.csv"
    clean_path = os.path.join(output_dir, clean_filename)
    clean_df.to_csv(clean_path, index=False)
    print(f"Cleaned data saved to: {clean_path}")
    print("-" * 50)

# Process lattice files if any
for i, file_path in enumerate(lattice_files):
    print(f"\nProcessing Lattice Table {i+1}:")
    df = pd.read_csv(file_path)
    print(f"Raw shape: {df.shape}")
    print("Raw data preview:")
    print(df.head())
    
    # Clean the data
    clean_df = clean_latam_remittance_data(df)
    print(f"\nCleaned shape: {clean_df.shape}")
    print("Cleaned data preview:")
    print(clean_df.head())
    
    # Save cleaned data
    clean_filename = f"latam_lattice_table_{i+1}_cleaned.csv"
    clean_path = os.path.join(output_dir, clean_filename)
    clean_df.to_csv(clean_path, index=False)
    print(f"Cleaned data saved to: {clean_path}")
    print("-" * 50)

print(f"\nAll LatAm files saved in: {output_dir}")
# Out:
# ANALYZING EXTRACTED LATAM DATA
# ==================================================
# Found 7 stream tables and 0 lattice tables
#
# Processing Stream Table 1:
# Raw shape: (90, 6)
# Raw data preview:
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN   NaN
# 1                                   Sending\tcountry  Receive\tcountry  Date
# 2                                        Afghanistan           Ecuador  2021
# 3                                                NaN            Mexico  2022
# 4                                                NaN            Panama  2022
#
#              3              4                    5
# 0          NaN            NaN                  NaN
# 1        Value           Unit               Source
# 2   0.03859066  USD\tmillions  Central\tBank\tData
# 3     0.295915  USD\tmillions  Central\tBank\tData
# 4  0.000387472  USD\tmillions                 INEC
#
# Cleaned shape: (89, 6)
# Cleaned data preview:
#                   0                 1     2            3              4  \
# 0  Sending\tcountry  Receive\tcountry  Date        Value           Unit
# 1       Afghanistan           Ecuador  2021   0.03859066  USD\tmillions
# 2               NaN            Mexico  2022     0.295915  USD\tmillions
# 3               NaN            Panama  2022  0.000387472  USD\tmillions
# 4           Albania           Ecuador  2021   1.89796382  USD\tmillions
#
#                      5
# 0               Source
# 1  Central\tBank\tData
# 2  Central\tBank\tData
# 3                 INEC
# 4  Central\tBank\tData
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_1_cleaned.csv
# --------------------------------------------------
#
# Processing Stream Table 2:
# Raw shape: (92, 6)
# Raw data preview:
#                                                    0                 1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN
# 1                                   Sending\tcountry  Receive\tcountry
# 2                           British\tVirgin\tIslands            Mexico
# 3                                                NaN            Panama
# 4                                 Brunei\tDarussalam           Ecuador
#
#         2         3              4                    5
# 0     NaN       NaN            NaN                  NaN
# 1  2022.0  7.559672  USD\tmillions               Source
# 2  2022.0  0.007236  USD\tmillions  Central\tBank\tData
# 3  2022.0  0.064767  USD\tmillions                 INEC
# 4  2021.0  0.001045  USD\tmillions  Central\tBank\tData
#
# Cleaned shape: (91, 6)
# Cleaned data preview:
#                           0                 1       2         3  \
# 0          Sending\tcountry  Receive\tcountry  2022.0  7.559672
# 1  British\tVirgin\tIslands            Mexico  2022.0  0.007236
# 2                       NaN            Panama  2022.0  0.064767
# 3        Brunei\tDarussalam           Ecuador  2021.0  0.001045
# 4                  Bulgaria           Ecuador  2021.0  0.091975
#
#                4                    5
# 0  USD\tmillions               Source
# 1  USD\tmillions  Central\tBank\tData
# 2  USD\tmillions                 INEC
# 3  USD\tmillions  Central\tBank\tData
# 4  USD\tmillions  Central\tBank\tData
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_2_cleaned.csv
# --------------------------------------------------
#
# Processing Stream Table 3:
# Raw shape: (91, 6)
# Raw data preview:
#                                                    0                 1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN
# 1                      Democratic\tRepublic\tof\tthe               NaN
# 2                                   Sending\tcountry  Receive\tcountry
# 3                                            Denmark           Ecuador
# 4                                                NaN            Mexico
#
#         2         3              4                    5
# 0     NaN       NaN            NaN                  NaN
# 1     NaN       NaN            NaN                  NaN
# 2  2022.0  0.377893  USD\tmillions               Source
# 3  2021.0  1.150536  USD\tmillions  Central\tBank\tData
# 4  2022.0  0.318480  USD\tmillions  Central\tBank\tData
#
# Cleaned shape: (89, 6)
# Cleaned data preview:
#                   0                 1       2         3              4  \
# 0  Sending\tcountry  Receive\tcountry  2022.0  0.377893  USD\tmillions
# 1           Denmark           Ecuador  2021.0  1.150536  USD\tmillions
# 2               NaN            Mexico  2022.0  0.318480  USD\tmillions
# 3               NaN            Panama  2022.0  0.230670  USD\tmillions
# 4          Djibouti            Mexico  2022.0  0.000503  USD\tmillions
#
#                      5
# 0               Source
# 1  Central\tBank\tData
# 2  Central\tBank\tData
# 3                 INEC
# 4  Central\tBank\tData
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_3_cleaned.csv
# --------------------------------------------------
#
# Processing Stream Table 4:
# Raw shape: (91, 6)
# Raw data preview:
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...                  NaN
# 1                                   Sending\tcountry     Receive\tcountry
# 2                                              Haiti          Costa\tRica
# 3                                                NaN  Dominican\tRepublic
# 4                                                NaN              Ecuador
#
#         2           3              4                    5
# 0     NaN         NaN            NaN                  NaN
# 1  2022.0    1.047404  USD\tmillions               Source
# 2  2022.0  117.596426  USD\tmillions  Central\tBank\tData
# 3  2022.0  117.596426  USD\tmillions  Central\tBank\tData
# 4  2021.0    1.373010  USD\tmillions  Central\tBank\tData
#
# Cleaned shape: (90, 6)
# Cleaned data preview:
#                   0                    1       2           3              4  \
# 0  Sending\tcountry     Receive\tcountry  2022.0    1.047404  USD\tmillions
# 1             Haiti          Costa\tRica  2022.0  117.596426  USD\tmillions
# 2               NaN  Dominican\tRepublic  2022.0  117.596426  USD\tmillions
# 3               NaN              Ecuador  2021.0    1.373010  USD\tmillions
# 4               NaN               Mexico  2022.0    0.703677  USD\tmillions
#
#                      5
# 0               Source
# 1  Central\tBank\tData
# 2  Central\tBank\tData
# 3  Central\tBank\tData
# 4  Central\tBank\tData
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_4_cleaned.csv
# --------------------------------------------------
#
# Processing Stream Table 5:
# Raw shape: (90, 6)
# Raw data preview:
#                                                    0                 1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN
# 1                                   Sending\tcountry  Receive\tcountry
# 2                                  Marshall\tIslands           Ecuador
# 3                                                NaN            Mexico
# 4                                         Martinique           Ecuador
#
#         2         3              4                    5
# 0     NaN       NaN            NaN                  NaN
# 1  2022.0  0.068785  USD\tmillions               Source
# 2  2021.0  0.030656  USD\tmillions  Central\tBank\tData
# 3  2022.0  0.001662  USD\tmillions  Central\tBank\tData
# 4  2021.0  0.005240  USD\tmillions  Central\tBank\tData
#
# Cleaned shape: (89, 6)
# Cleaned data preview:
#                    0                 1       2          3              4  \
# 0   Sending\tcountry  Receive\tcountry  2022.0   0.068785  USD\tmillions
# 1  Marshall\tIslands           Ecuador  2021.0   0.030656  USD\tmillions
# 2                NaN            Mexico  2022.0   0.001662  USD\tmillions
# 3         Martinique           Ecuador  2021.0   0.005240  USD\tmillions
# 4                NaN             Haiti  2019.0  39.439518  USD\tmillions
#
#                      5
# 0               Source
# 1  Central\tBank\tData
# 2  Central\tBank\tData
# 3  Central\tBank\tData
# 4  Central\tBank\tData
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_5_cleaned.csv
# --------------------------------------------------
#
# Processing Stream Table 6:
# Raw shape: (91, 6)
# Raw data preview:
#                                                    0                 1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN
# 1                                   Sending\tcountry  Receive\tcountry
# 2                                Republic\tof\tKorea            Panama
# 3                              Republic\tof\tMoldova           Ecuador
# 4                                                NaN            Mexico
#
#         2            3              4                    5
# 0     NaN          NaN            NaN                  NaN
# 1  2022.0     0.188341  USD\tmillions               Source
# 2  2022.0  0.418495932  USD\tmillions                 INEC
# 3  2021.0   0.11212232  USD\tmillions  Central\tBank\tData
# 4  2022.0     0.003839  USD\tmillions  Central\tBank\tData
#
# Cleaned shape: (90, 6)
# Cleaned data preview:
#                        0                 1       2            3  \
# 0       Sending\tcountry  Receive\tcountry  2022.0     0.188341
# 1    Republic\tof\tKorea            Panama  2022.0  0.418495932
# 2  Republic\tof\tMoldova           Ecuador  2021.0   0.11212232
# 3                    NaN            Mexico  2022.0     0.003839
# 4                Réunion            Mexico  2022.0     0.000868
#
#                4                    5
# 0  USD\tmillions               Source
# 1  USD\tmillions                 INEC
# 2  USD\tmillions  Central\tBank\tData
# 3  USD\tmillions  Central\tBank\tData
# 4  USD\tmillions  Central\tBank\tData
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_6_cleaned.csv
# --------------------------------------------------
#
# Processing Stream Table 7:
# Raw shape: (76, 6)
# Raw data preview:
#                                                    0                 1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN
# 1                                   Sending\tcountry  Receive\tcountry
# 2                                         Tajikistan            Mexico
# 3                                           Thailand           Ecuador
# 4                                                NaN            Mexico
#
#         2           3              4                    5
# 0     NaN         NaN            NaN                  NaN
# 1  2021.0      0.0488  USD\tmillions               Source
# 2  2022.0     0.00556  USD\tmillions  Central\tBank\tData
# 3  2021.0  0.15738123  USD\tmillions  Central\tBank\tData
# 4  2022.0     0.08895  USD\tmillions  Central\tBank\tData
#
# Cleaned shape: (75, 6)
# Cleaned data preview:
#                   0                 1       2            3              4  \
# 0  Sending\tcountry  Receive\tcountry  2021.0       0.0488  USD\tmillions
# 1        Tajikistan            Mexico  2022.0      0.00556  USD\tmillions
# 2          Thailand           Ecuador  2021.0   0.15738123  USD\tmillions
# 3               NaN            Mexico  2022.0      0.08895  USD\tmillions
# 4               NaN            Panama  2022.0  0.067822704  USD\tmillions
#
#                      5
# 0               Source
# 1  Central\tBank\tData
# 2  Central\tBank\tData
# 3  Central\tBank\tData
# 4                 INEC
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm\latam_stream_table_7_cleaned.csv
# --------------------------------------------------
#
# All LatAm files saved in: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm

# %%
# Summary of LatAm extraction results
print("LATAM PDF EXTRACTION SUMMARY")
print("="*50)
print("🇱🇦 Latin America Central Bank PDF Analysis")
print("📄 Source: Remitscope_LatAm_central_bank.pdf")
print("📊 Pages analyzed: 1-7")
print()

# Count the extracted files
stream_count = len(glob.glob(os.path.join(output_dir, "latam_stream_table_*.csv")))
lattice_count = len(glob.glob(os.path.join(output_dir, "latam_lattice_table_*.csv")))

print("✅ Extraction Results:")
print(f"   • Stream flavor: Found {stream_count} tables")
print(f"   • Lattice flavor: Found {lattice_count} tables")
print()

if stream_count > 0:
    print("📊 Stream Tables Summary:")
    for i in range(stream_count):
        file_path = os.path.join(output_dir, f"latam_stream_table_{i+1}.csv")
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            print(f"   • Table {i+1}: {df.shape[0]} rows × {df.shape[1]} columns")

if lattice_count > 0:
    print("📊 Lattice Tables Summary:")
    for i in range(lattice_count):
        file_path = os.path.join(output_dir, f"latam_lattice_table_{i+1}.csv")
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            print(f"   • Table {i+1}: {df.shape[0]} rows × {df.shape[1]} columns")

print()
print("💾 Files created in output directory:")
print("   • Raw extracted tables (latam_stream_table_*.csv)")
print("   • Cleaned tables (latam_stream_table_*_cleaned.csv)")
if lattice_count > 0:
    print("   • Lattice tables (latam_lattice_table_*.csv)")
print()
print(f"📁 Location: {output_dir}")
print()
print("🎯 Next Steps:")
print("   1. Review extracted tables for data quality")
print("   2. Combine tables if they contain related data")
print("   3. Analyze remittance flows for Latin America region")
# Out:
# LATAM PDF EXTRACTION SUMMARY
# ==================================================
# 🇱🇦 Latin America Central Bank PDF Analysis
# 📄 Source: Remitscope_LatAm_central_bank.pdf
# 📊 Pages analyzed: 1-7
#
# ✅ Extraction Results:
#    • Stream flavor: Found 14 tables
#    • Lattice flavor: Found 0 tables
#
# 📊 Stream Tables Summary:
#    • Table 1: 90 rows × 6 columns
#    • Table 2: 92 rows × 6 columns
#    • Table 3: 91 rows × 6 columns
#    • Table 4: 91 rows × 6 columns
#    • Table 5: 90 rows × 6 columns
#    • Table 6: 91 rows × 6 columns
#    • Table 7: 76 rows × 6 columns
#
# 💾 Files created in output directory:
#    • Raw extracted tables (latam_stream_table_*.csv)
#    • Cleaned tables (latam_stream_table_*_cleaned.csv)
#
# 📁 Location: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm
#
# 🎯 Next Steps:
#    1. Review extracted tables for data quality
#    2. Combine tables if they contain related data
#    3. Analyze remittance flows for Latin America region
#    • Table 7: 76 rows × 6 columns
#
# 💾 Files created in output directory:
#    • Raw extracted tables (latam_stream_table_*.csv)
#    • Cleaned tables (latam_stream_table_*_cleaned.csv)
#
# 📁 Location: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\LatAm
#
# 🎯 Next Steps:
#    1. Review extracted tables for data quality
#    2. Combine tables if they contain related data
#    3. Analyze remittance flows for Latin America region

# %%
# DETAILED ANALYSIS OF LATAM EXTRACTED DATA
print("DETAILED LATAM DATA ANALYSIS")
print("="*60)

# Load and compare the first extracted table (if available)
stream_files = glob.glob(os.path.join(output_dir, "latam_stream_table_*.csv"))

if len(stream_files) > 0:
    # Load first table
    first_table_path = stream_files[0]
    df_raw = pd.read_csv(first_table_path)
    
    # Load cleaned version
    clean_table_path = first_table_path.replace('.csv', '_cleaned.csv')
    if os.path.exists(clean_table_path):
        df_clean = pd.read_csv(clean_table_path)
    else:
        df_clean = clean_latam_remittance_data(df_raw)
    
    print("📊 COMPARISON: RAW vs CLEANED DATA")
    print("-" * 40)
    print("RAW DATA (First 10 rows):")
    print(df_raw.head(10))
    print(f"Raw Shape: {df_raw.shape}")
    print()
    
    print("CLEANED DATA (First 10 rows):")
    print(df_clean.head(10))
    print(f"Cleaned Shape: {df_clean.shape}")
    print()
    
    print("🔍 DATA QUALITY ANALYSIS:")
    print("-" * 40)
    print(f"1. Rows removed during cleaning: {df_raw.shape[0] - df_clean.shape[0]}")
    print(f"2. Columns in dataset: {df_clean.shape[1]}")
    print(f"3. Non-null values per column:")
    for i, col in enumerate(df_clean.columns):
        non_null_count = df_clean[col].count()
        print(f"   Column {i+1}: {non_null_count}/{len(df_clean)} ({non_null_count/len(df_clean)*100:.1f}%)")
    
    print()
    print("📈 SAMPLE DATA PREVIEW:")
    print("-" * 40)
    print("Middle section of cleaned data:")
    mid_point = len(df_clean) // 2
    print(df_clean.iloc[mid_point:mid_point+5])
    
    print()
    print("📋 COLUMN ANALYSIS:")
    print("-" * 40)
    for i, col in enumerate(df_clean.columns):
        sample_values = df_clean[col].dropna().head(3).tolist()
        print(f"Column {i+1} sample values: {sample_values}")

else:
    print("❌ No tables were extracted from the LatAm PDF")
    print("This could mean:")
    print("   • The PDF doesn't contain extractable tables")
    print("   • Tables are in image format (need OCR)")
    print("   • Different extraction parameters needed")
    print("   • Pages 1-7 don't contain the tables")

print()
print("🎯 RECOMMENDATIONS:")
print("-" * 40)
if len(stream_files) > 0:
    print("✅ Extraction successful! Consider:")
    print("   • Validating country names and remittance values")
    print("   • Checking for currency information")
    print("   • Combining multiple tables if they're related")
    print("   • Creating visualizations for regional analysis")
else:
    print("⚠️ Extraction needs adjustment:")
    print("   • Try different page ranges")
    print("   • Test with different camelot parameters")
    print("   • Consider alternative extraction methods")
    print("   • Check if PDF is text-based or image-based")
# Out:
# DETAILED LATAM DATA ANALYSIS
# ============================================================
# 📊 COMPARISON: RAW vs CLEANED DATA
# ----------------------------------------
# RAW DATA (First 10 rows):
#                                                    0                 1     2  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...               NaN   NaN
# 1                                   Sending\tcountry  Receive\tcountry  Date
# 2                                        Afghanistan           Ecuador  2021
# 3                                                NaN            Mexico  2022
# 4                                                NaN            Panama  2022
# 5                                            Albania           Ecuador  2021
# 6                                                NaN            Mexico  2022
# 7                                                NaN            Panama  2022
# 8                                    American\tSamoa           Ecuador  2021
# 9                                             Angola            Brazil  2022
#
#              3              4                    5
# 0          NaN            NaN                  NaN
# 1        Value           Unit               Source
# 2   0.03859066  USD\tmillions  Central\tBank\tData
# 3     0.295915  USD\tmillions  Central\tBank\tData
# 4  0.000387472  USD\tmillions                 INEC
# 5   1.89796382  USD\tmillions  Central\tBank\tData
# 6     0.023831  USD\tmillions  Central\tBank\tData
# 7  0.038935399  USD\tmillions                 INEC
# 8    0.0553291  USD\tmillions  Central\tBank\tData
# 9   8.32422068  USD\tmillions  Central\tBank\tData
# Raw Shape: (90, 6)
#
# CLEANED DATA (First 10 rows):
#                   0                 1     2            3              4  \
# 0  Sending\tcountry  Receive\tcountry  Date        Value           Unit
# 1       Afghanistan           Ecuador  2021   0.03859066  USD\tmillions
# 2               NaN            Mexico  2022     0.295915  USD\tmillions
# 3               NaN            Panama  2022  0.000387472  USD\tmillions
# 4           Albania           Ecuador  2021   1.89796382  USD\tmillions
# 5               NaN            Mexico  2022     0.023831  USD\tmillions
# 6               NaN            Panama  2022  0.038935399  USD\tmillions
# 7   American\tSamoa           Ecuador  2021    0.0553291  USD\tmillions
# 8            Angola            Brazil  2022   8.32422068  USD\tmillions
# 9               NaN           Ecuador  2021   0.00924998  USD\tmillions
#
#                      5
# 0               Source
# 1  Central\tBank\tData
# 2  Central\tBank\tData
# 3                 INEC
# 4  Central\tBank\tData
# 5  Central\tBank\tData
# 6                 INEC
# 7  Central\tBank\tData
# 8  Central\tBank\tData
# 9  Central\tBank\tData
# Cleaned Shape: (89, 6)
#
# 🔍 DATA QUALITY ANALYSIS:
# ----------------------------------------
# 1. Rows removed during cleaning: 1
# 2. Columns in dataset: 6
# 3. Non-null values per column:
#    Column 1: 26/89 (29.2%)
#    Column 2: 89/89 (100.0%)
#    Column 3: 89/89 (100.0%)
#    Column 4: 89/89 (100.0%)
#    Column 5: 89/89 (100.0%)
#    Column 6: 88/89 (98.9%)
#
# 📈 SAMPLE DATA PREVIEW:
# ----------------------------------------
# Middle section of cleaned data:
#           0        1     2             3              4                    5
# 44      NaN  Jamaica  2022  21.752802625  USD\tmillions  Central\tBank\tData
# 45      NaN   Mexico  2022      1.002488  USD\tmillions  Central\tBank\tData
# 46      NaN   Panama  2022   0.964305300  USD\tmillions                 INEC
# 47  Bahrain  Ecuador  2021    0.06671668  USD\tmillions  Central\tBank\tData
# 48      NaN   Mexico  2022      0.053798  USD\tmillions  Central\tBank\tData
#
# 📋 COLUMN ANALYSIS:
# ----------------------------------------
# Column 1 sample values: ['Sending\tcountry', 'Afghanistan', 'Albania']
# Column 2 sample values: ['Receive\tcountry', 'Ecuador', 'Mexico']
# Column 3 sample values: ['Date', '2021', '2022']
# Column 4 sample values: ['Value', '0.03859066', '0.295915']
# Column 5 sample values: ['Unit', 'USD\tmillions', 'USD\tmillions']
# Column 6 sample values: ['Source', 'Central\tBank\tData', 'Central\tBank\tData']
#
# 🎯 RECOMMENDATIONS:
# ----------------------------------------
# ✅ Extraction successful! Consider:
#    • Validating country names and remittance values
#    • Checking for currency information
#    • Combining multiple tables if they're related
#    • Creating visualizations for regional analysis
