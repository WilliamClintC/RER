# %%
# Load the specified CSV file
import pandas as pd
df = pd.read_csv(r"C:\Users\Owner\Desktop\Devereux\data\estat_ert_bil_eur_a_en.csv\estat_ert_bil_eur_a_en.csv")
df
# Out:
#      STRUCTURE              STRUCTURE_ID  \
# 0     dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 1     dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 2     dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 3     dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 4     dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# ...        ...                       ...
# 8021  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 8022  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 8023  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 8024  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 8025  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
#
#                              STRUCTURE_NAME freq Time frequency statinfo  \
# 0     Euro/ECU exchange rates - annual data    A         Annual      AVG
# 1     Euro/ECU exchange rates - annual data    A         Annual      AVG
# 2     Euro/ECU exchange rates - annual data    A         Annual      AVG
# 3     Euro/ECU exchange rates - annual data    A         Annual      AVG
# 4     Euro/ECU exchange rates - annual data    A         Annual      AVG
# ...

# %%
# show me all unique entries in column TIME_PERIOD
df['TIME_PERIOD'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024, 1995, 1996, 1997, 1998, 1999, 2000, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1976,
#        1977, 1978, 1979, 1980, 1981, 1975, 1971, 1972, 1973, 1974])

# %%
#restrict only my TIME_PERIOD to 2000-2021
df = df[df['TIME_PERIOD'].between(2000, 2021)]
df['TIME_PERIOD'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2000])

# %%
#name me all unique entries in currency
df['currency'].unique()
# Out:
# array(['AED', 'AFN', 'ALL', 'AMD', 'ANG', 'AOA', 'ARS', 'AUD', 'AWG',
#        'AZN', 'BAM', 'BBD', 'BDT', 'BGN', 'BHD', 'BIF', 'BMD', 'BND',
#        'BOB', 'BRL', 'BSD', 'BTN', 'BWP', 'BYN', 'BZD', 'CAD', 'CDF',
#        'CHF', 'CLP', 'CNY', 'COP', 'CRC', 'CUP', 'CVE', 'CZK', 'DJF',
#        'DKK', 'DOP', 'DZD', 'EGP', 'ERN', 'ETB', 'FJD', 'FKP', 'GBP',
#        'GEL', 'GHS', 'GIP', 'GMD', 'GNF', 'GTQ', 'GYD', 'HKD', 'HNL',
#        'HTG', 'HUF', 'IDR', 'ILS', 'INR', 'IQD', 'IRR', 'ISK', 'JMD',
#        'JOD', 'JPY', 'KES', 'KGS', 'KHR', 'KMF', 'KRW', 'KWD', 'KYD',
#        'KZT', 'LAK', 'LBP', 'LKR', 'LRD', 'LSL', 'LYD', 'MAD', 'MDL',
#        'MGA', 'MKD', 'MMK', 'MNT', 'MOP', 'MRU', 'MUR', 'MVR', 'MWK',
#        'MXN', 'MYR', 'MZN', 'NAD', 'NGN', 'NIO', 'NOK', 'NPR', 'NZD',
#        'OMR', 'PAB', 'PEN', 'PGK', 'PHP', 'PKR', 'PLN', 'PYG', 'QAR',
#        'RON', 'RSD', 'RUB', 'RWF', 'SAR', 'SBD', 'SCR', 'SDG', 'SEK',
# ...

# %%
# fitler currency for only these BGN (Bulgaria)

# CZK (Czech Republic)

# DKK (Denmark)

# HUF (Hungary)

# PLN (Poland)

# RON (Romania)

# SEK (Sweden)
df = df[df['currency'].isin(['BGN', 'CZK', 'DKK', 'HUF', 'PLN', 'RON', 'SEK'])]
df
# Out:
#      STRUCTURE              STRUCTURE_ID  \
# 354   dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 355   dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 356   dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 357   dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 358   dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# ...        ...                       ...
# 7201  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 7202  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 7203  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 7204  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
# 7205  dataflow  ESTAT:ERT_BIL_EUR_A(1.0)
#
#                              STRUCTURE_NAME freq Time frequency statinfo  \
# 354   Euro/ECU exchange rates - annual data    A         Annual      AVG
# 355   Euro/ECU exchange rates - annual data    A         Annual      AVG
# 356   Euro/ECU exchange rates - annual data    A         Annual      AVG
# 357   Euro/ECU exchange rates - annual data    A         Annual      AVG
# 358   Euro/ECU exchange rates - annual data    A         Annual      AVG
# ...
