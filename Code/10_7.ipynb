# %%
import fitz  # PyMuPDF
import pandas as pd
import re
import os

# Path to the PDF file
pdf_path = r"C:\Users\clint\Desktop\RER\data\Remittance_4\Africa.pdf"

# Check if file exists
if os.path.exists(pdf_path):
    print(f"PDF found: {pdf_path}")
else:
    print(f"PDF not found at: {pdf_path}")
    print("Please check the file path.")
# Out:
# PDF found: C:\Users\clint\Desktop\RER\data\Remittance_3\Remitscope_Africa_central_bank.pdf

# %%
import camelot
import pandas as pd
import re

# Try to extract tables using Camelot
try:
    # Extract tables from first page only
    tables = camelot.read_pdf(pdf_path, pages='1', flavor='stream')
    print(f"Number of tables found: {len(tables)}")
    
    if len(tables) > 0:
        for i, table in enumerate(tables):
            print(f"\nTable {i+1}:")
            print(f"Shape: {table.df.shape}")
            print(table.df.head(10))
            print("="*50)
    else:
        print("No tables found with Camelot")
        
except Exception as e:
    print(f"Error with Camelot: {e}")
    print("Let's try manual parsing...")
# Out:
# Number of tables found: 2
#
# Table 1:
# Shape: (90, 6)
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                            Algeria              Senegal
# 3                                          Australia             Ethiopia
# 4                                                                   Kenya
# 5                                                                  Uganda
# 6                                            Austria                Kenya
# 7                                            Bahamas                Kenya
# 8                                            Bahrain                Kenya
# 9                                                                 Morocco
#
#       2                  3              4                             5
# 0
# 1                    Value           Unit                        Source
# 2  2021        0.183414825  USD\tmillions                         BCEAO
# 3  2020        13.59617511  USD\tmillions  National\tBank\tof\tEthiopia
# 4  2024  184,497.099695719  USD\tmillions      Central\tBank\tof\tKenya
# 5  2022                 22  USD\tmillions              Bank\tof\tUganda
# 6  2024   13,169.065145833  USD\tmillions      Central\tBank\tof\tKenya
# 7  2024    1,453.632639905  USD\tmillions      Central\tBank\tof\tKenya
# 8  2024    5,004.769090469  USD\tmillions      Central\tBank\tof\tKenya
# 9  2020         30.3408085  USD\tmillions              Bank\tAl-Maghrib
# ==================================================
#
# Table 2:
# Shape: (43, 5)
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                      South\tAfrica       Ethiopia\n2020
# 3                                                             Kenya\n2024
# 4                                                           Senegal\n2021
# 5                                                            Uganda\n2022
# 6                                       South\tSudan       Ethiopia\n2020
# 7                                                             Kenya\n2024
# 8                                                            Uganda\n2022
# 9                                              Spain        Morocco\n2020
#
#                   2              3                             4
# 0
# 1             Value  USD\tmillions                        Source
# 2       67.93372415  USD\tmillions  National\tBank\tof\tEthiopia
# 3  24,095.095706679  USD\tmillions      Central\tBank\tof\tKenya
# 4      14.579840557  USD\tmillions                         BCEAO
# 5              28.7  USD\tmillions              Bank\tof\tUganda
# 6       11.33937986  USD\tmillions  National\tBank\tof\tEthiopia
# 7   5,789.706224355  USD\tmillions      Central\tBank\tof\tKenya
# 8             113.3  USD\tmillions              Bank\tof\tUganda
# 9       705.7301285  USD\tmillions              Bank\tAl-Maghrib
# ==================================================

# %%
# Test both lattice and stream approaches
import os

# Create output directory if it doesn't exist
output_dir = r"C:\Users\clint\Desktop\RER\_output\data\Remittance_3"
os.makedirs(output_dir, exist_ok=True)

print("Testing both Camelot approaches: lattice and stream")
print("="*60)

# Approach 1: Stream flavor (better for tables without clear borders)
print("\n1. TESTING STREAM FLAVOR")
print("-" * 30)
try:
    tables_stream = camelot.read_pdf(pdf_path, pages='1', flavor='stream')
    print(f"Stream - Number of tables found: {len(tables_stream)}")
    
    if len(tables_stream) > 0:
        for i, table in enumerate(tables_stream):
            print(f"\nStream Table {i+1}:")
            print(f"Shape: {table.df.shape}")
            print(f"Accuracy: {table.accuracy:.2f}")
            print("Preview (first 5 rows):")
            print(table.df.head())
            
            # Save to CSV
            csv_filename = f"stream_table_{i+1}.csv"
            csv_path = os.path.join(output_dir, csv_filename)
            table.df.to_csv(csv_path, index=False)
            print(f"Saved to: {csv_path}")
            print("-" * 40)
    else:
        print("No tables found with stream flavor")
        
except Exception as e:
    print(f"Error with stream flavor: {e}")

print("\n" + "="*60)

# Approach 2: Lattice flavor (better for tables with clear borders)
print("\n2. TESTING LATTICE FLAVOR")
print("-" * 30)
try:
    tables_lattice = camelot.read_pdf(pdf_path, pages='1', flavor='lattice')
    print(f"Lattice - Number of tables found: {len(tables_lattice)}")
    
    if len(tables_lattice) > 0:
        for i, table in enumerate(tables_lattice):
            print(f"\nLattice Table {i+1}:")
            print(f"Shape: {table.df.shape}")
            print(f"Accuracy: {table.accuracy:.2f}")
            print("Preview (first 5 rows):")
            print(table.df.head())
            
            # Save to CSV
            csv_filename = f"lattice_table_{i+1}.csv"
            csv_path = os.path.join(output_dir, csv_filename)
            table.df.to_csv(csv_path, index=False)
            print(f"Saved to: {csv_path}")
            print("-" * 40)
    else:
        print("No tables found with lattice flavor")
        
except Exception as e:
    print(f"Error with lattice flavor: {e}")

print("\n" + "="*60)
print("SUMMARY:")
print(f"Output directory: {output_dir}")
print("Check the CSV files to compare the results from both approaches.")
# Out:
# Testing both Camelot approaches: lattice and stream
# ============================================================
#
# 1. TESTING STREAM FLAVOR
# ------------------------------
# Stream - Number of tables found: 2
#
# Stream Table 1:
# Shape: (90, 6)
# Accuracy: 99.82
# Preview (first 5 rows):
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                            Algeria              Senegal
# 3                                          Australia             Ethiopia
# 4                                                                   Kenya
#
#       2                  3              4                             5
# 0
# 1                    Value           Unit                        Source
# 2  2021        0.183414825  USD\tmillions                         BCEAO
# 3  2020        13.59617511  USD\tmillions  National\tBank\tof\tEthiopia
# 4  2024  184,497.099695719  USD\tmillions      Central\tBank\tof\tKenya
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\stream_table_1.csv
# ----------------------------------------
#
# Stream Table 2:
# Shape: (43, 5)
# Accuracy: 99.73
# Preview (first 5 rows):
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                      South\tAfrica       Ethiopia\n2020
# 3                                                             Kenya\n2024
# 4                                                           Senegal\n2021
#
#                   2              3                             4
# 0
# 1             Value  USD\tmillions                        Source
# 2       67.93372415  USD\tmillions  National\tBank\tof\tEthiopia
# 3  24,095.095706679  USD\tmillions      Central\tBank\tof\tKenya
# 4      14.579840557  USD\tmillions                         BCEAO
# Saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\stream_table_2.csv
# ----------------------------------------
#
# ============================================================
#
# 2. TESTING LATTICE FLAVOR
# ------------------------------
# Lattice - Number of tables found: 0
# No tables found with lattice flavor
#
# ============================================================
# SUMMARY:
# Output directory: C:\Users\clint\Desktop\RER\_output\data\Remittance_3
# Check the CSV files to compare the results from both approaches.

# %%
# Load and clean the extracted data
print("ANALYZING EXTRACTED DATA")
print("="*50)

# Load the CSV files
stream_table1_path = os.path.join(output_dir, "stream_table_1.csv")
stream_table2_path = os.path.join(output_dir, "stream_table_2.csv")

if os.path.exists(stream_table1_path):
    df1 = pd.read_csv(stream_table1_path)
    print("Stream Table 1 - Raw data:")
    print(f"Shape: {df1.shape}")
    print(df1.head(10))
    print("\n" + "-"*30)

if os.path.exists(stream_table2_path):
    df2 = pd.read_csv(stream_table2_path)
    print("Stream Table 2 - Raw data:")
    print(f"Shape: {df2.shape}")
    print(df2.head(10))
    print("\n" + "-"*30)

# Clean and combine the data
print("\nCLEANING THE DATA...")

# Function to clean the dataframes
def clean_remittance_data(df):
    """Clean the extracted remittance data"""
    # Skip the first few rows that contain headers
    clean_df = df.copy()
    
    # Find where the actual data starts (after header rows)
    data_start = 0
    for i, row in clean_df.iterrows():
        if 'Sending' in str(row.iloc[0]) and 'country' in str(row.iloc[0]):
            data_start = i + 1
            break
    
    if data_start > 0:
        clean_df = clean_df.iloc[data_start:].reset_index(drop=True)
    
    # Remove empty rows
    clean_df = clean_df.dropna(how='all').reset_index(drop=True)
    
    return clean_df

# Clean both tables
if 'df1' in locals():
    clean_df1 = clean_remittance_data(df1)
    print(f"Cleaned Table 1 shape: {clean_df1.shape}")
    print("Sample of cleaned data:")
    print(clean_df1.head())
    
    # Save cleaned data
    clean_path1 = os.path.join(output_dir, "stream_table_1_cleaned.csv")
    clean_df1.to_csv(clean_path1, index=False)
    print(f"Cleaned data saved to: {clean_path1}")

if 'df2' in locals():
    clean_df2 = clean_remittance_data(df2)
    print(f"\nCleaned Table 2 shape: {clean_df2.shape}")
    print("Sample of cleaned data:")
    print(clean_df2.head())
    
    # Save cleaned data
    clean_path2 = os.path.join(output_dir, "stream_table_2_cleaned.csv")
    clean_df2.to_csv(clean_path2, index=False)
    print(f"Cleaned data saved to: {clean_path2}")

print(f"\nAll files saved in: {output_dir}")
# Out:
# ANALYZING EXTRACTED DATA
# ==================================================
# Stream Table 1 - Raw data:
# Shape: (90, 6)
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...                  NaN
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                            Algeria              Senegal
# 3                                          Australia             Ethiopia
# 4                                                NaN                Kenya
# 5                                                NaN               Uganda
# 6                                            Austria                Kenya
# 7                                            Bahamas                Kenya
# 8                                            Bahrain                Kenya
# 9                                                NaN              Morocco
#
#         2                  3              4                             5
# 0     NaN                NaN            NaN                           NaN
# 1     NaN              Value           Unit                        Source
# 2  2021.0        0.183414825  USD\tmillions                         BCEAO
# 3  2020.0        13.59617511  USD\tmillions  National\tBank\tof\tEthiopia
# 4  2024.0  184,497.099695719  USD\tmillions      Central\tBank\tof\tKenya
# 5  2022.0                 22  USD\tmillions              Bank\tof\tUganda
# 6  2024.0   13,169.065145833  USD\tmillions      Central\tBank\tof\tKenya
# 7  2024.0    1,453.632639905  USD\tmillions      Central\tBank\tof\tKenya
# 8  2024.0    5,004.769090469  USD\tmillions      Central\tBank\tof\tKenya
# 9  2020.0         30.3408085  USD\tmillions              Bank\tAl-Maghrib
#
# ------------------------------
# Stream Table 2 - Raw data:
# Shape: (43, 5)
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...                  NaN
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                      South\tAfrica       Ethiopia\n2020
# 3                                                NaN          Kenya\n2024
# 4                                                NaN        Senegal\n2021
# 5                                                NaN         Uganda\n2022
# 6                                       South\tSudan       Ethiopia\n2020
# 7                                                NaN          Kenya\n2024
# 8                                                NaN         Uganda\n2022
# 9                                              Spain        Morocco\n2020
#
#                   2              3                             4
# 0               NaN            NaN                           NaN
# 1             Value  USD\tmillions                        Source
# 2       67.93372415  USD\tmillions  National\tBank\tof\tEthiopia
# 3  24,095.095706679  USD\tmillions      Central\tBank\tof\tKenya
# 4      14.579840557  USD\tmillions                         BCEAO
# 5              28.7  USD\tmillions              Bank\tof\tUganda
# 6       11.33937986  USD\tmillions  National\tBank\tof\tEthiopia
# 7   5,789.706224355  USD\tmillions      Central\tBank\tof\tKenya
# 8             113.3  USD\tmillions              Bank\tof\tUganda
# 9       705.7301285  USD\tmillions              Bank\tAl-Maghrib
#
# ------------------------------
#
# CLEANING THE DATA...
# Cleaned Table 1 shape: (88, 6)
# Sample of cleaned data:
#            0         1       2                  3              4  \
# 0    Algeria   Senegal  2021.0        0.183414825  USD\tmillions
# 1  Australia  Ethiopia  2020.0        13.59617511  USD\tmillions
# 2        NaN     Kenya  2024.0  184,497.099695719  USD\tmillions
# 3        NaN    Uganda  2022.0                 22  USD\tmillions
# 4    Austria     Kenya  2024.0   13,169.065145833  USD\tmillions
#
#                               5
# 0                         BCEAO
# 1  National\tBank\tof\tEthiopia
# 2      Central\tBank\tof\tKenya
# 3              Bank\tof\tUganda
# 4      Central\tBank\tof\tKenya
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\stream_table_1_cleaned.csv
#
# Cleaned Table 2 shape: (41, 5)
# Sample of cleaned data:
#                0               1                 2              3  \
# 0  South\tAfrica  Ethiopia\n2020       67.93372415  USD\tmillions
# 1            NaN     Kenya\n2024  24,095.095706679  USD\tmillions
# 2            NaN   Senegal\n2021      14.579840557  USD\tmillions
# 3            NaN    Uganda\n2022              28.7  USD\tmillions
# 4   South\tSudan  Ethiopia\n2020       11.33937986  USD\tmillions
#
#                               4
# 0  National\tBank\tof\tEthiopia
# 1      Central\tBank\tof\tKenya
# 2                         BCEAO
# 3              Bank\tof\tUganda
# 4  National\tBank\tof\tEthiopia
# Cleaned data saved to: C:\Users\clint\Desktop\RER\_output\data\Remittance_3\stream_table_2_cleaned.csv
#
# All files saved in: C:\Users\clint\Desktop\RER\_output\data\Remittance_3

# %%
# Summary of extraction results
print("EXTRACTION SUMMARY")
print("="*50)
print("✅ Successfully tested both Camelot approaches:")
print("   • Stream flavor: Extracting tables from page 1 only")
print("   • Lattice flavor: Extracting tables from page 1 only")
print()
print("📊 Extracted data from page 1 contains:")
print("   • Remittance data tables from the first page of the PDF")
print()
print("💾 Files created:")
print("   • stream_table_1.csv - Raw extracted table from page 1")
print("   • stream_table_1_cleaned.csv - Cleaned table from page 1")
print("   • Additional tables if found on page 1")
print()
print(f"📁 Location: {output_dir}")
print()
print("🎯 Recommendation: Use STREAM flavor for this PDF type")
print("   Stream flavor works better for PDFs without clear table borders")
print("   Now extracting from page 1 only as requested")
# Out:
# EXTRACTION SUMMARY
# ==================================================
# ✅ Successfully tested both Camelot approaches:
#    • Stream flavor: Found 2 tables with high accuracy (99.82% and 99.73%)
#    • Lattice flavor: Found 0 tables (PDF likely doesn't have clear borders)
#
# 📊 Extracted data contains:
#    • Table 1: 90 rows × 6 columns - Main remittance data
#    • Table 2: 43 rows × 5 columns - Additional remittance data
#
# 💾 Files created:
#    • stream_table_1.csv - Raw extracted table 1
#    • stream_table_2.csv - Raw extracted table 2
#    • stream_table_1_cleaned.csv - Cleaned table 1
#    • stream_table_2_cleaned.csv - Cleaned table 2
#
# 📁 Location: C:\Users\clint\Desktop\RER\_output\data\Remittance_3
#
# 🎯 Recommendation: Use STREAM flavor for this PDF type
#    Stream flavor works better for PDFs without clear table borders

# %%
# DIFFERENCE BETWEEN CLEANED AND UNCLEANED DATA
print("COMPARISON: UNCLEANED vs CLEANED DATA")
print("="*60)

print("📊 UNCLEANED DATA (Raw from PDF extraction):")
print("-" * 40)
print("Table 1 - First 10 rows of raw data:")
print(df1.head(10))
print(f"Shape: {df1.shape}")
print()

print("Table 2 - First 10 rows of raw data:")
print(df2.head(10))
print(f"Shape: {df2.shape}")
print()

print("🧹 CLEANED DATA (After processing):")
print("-" * 40)
print("Table 1 - First 10 rows of cleaned data:")
print(clean_df1.head(10))
print(f"Shape: {clean_df1.shape}")
print()

print("Table 2 - First 10 rows of cleaned data:")
print(clean_df2.head(10))
print(f"Shape: {clean_df2.shape}")
print()

print("🔍 KEY DIFFERENCES:")
print("-" * 40)
print("1. HEADER ROWS: Uncleaned data contains PDF metadata and headers")
print("   - Raw data includes indicator descriptions, column headers")
print("   - Cleaned data starts from actual data rows")
print()
print("2. EMPTY ROWS: Uncleaned data may have empty/null rows")
print("   - Raw data preserves PDF structure including spaces")
print("   - Cleaned data removes empty rows")
print()
print("3. DATA STRUCTURE: Cleaned data is more analysis-ready")
print("   - Raw data preserves original PDF formatting")
print("   - Cleaned data has consistent column structure")
print()
print("4. SIZE DIFFERENCE:")
print(f"   - Table 1: {df1.shape[0]} rows → {clean_df1.shape[0]} rows")
print(f"   - Table 2: {df2.shape[0]} rows → {clean_df2.shape[0]} rows")
# Out:
# COMPARISON: UNCLEANED vs CLEANED DATA
# ============================================================
# 📊 UNCLEANED DATA (Raw from PDF extraction):
# ----------------------------------------
# Table 1 - First 10 rows of raw data:
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...                  NaN
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                            Algeria              Senegal
# 3                                          Australia             Ethiopia
# 4                                                NaN                Kenya
# 5                                                NaN               Uganda
# 6                                            Austria                Kenya
# 7                                            Bahamas                Kenya
# 8                                            Bahrain                Kenya
# 9                                                NaN              Morocco
#
#         2                  3              4                             5
# 0     NaN                NaN            NaN                           NaN
# 1     NaN              Value           Unit                        Source
# 2  2021.0        0.183414825  USD\tmillions                         BCEAO
# 3  2020.0        13.59617511  USD\tmillions  National\tBank\tof\tEthiopia
# 4  2024.0  184,497.099695719  USD\tmillions      Central\tBank\tof\tKenya
# 5  2022.0                 22  USD\tmillions              Bank\tof\tUganda
# 6  2024.0   13,169.065145833  USD\tmillions      Central\tBank\tof\tKenya
# 7  2024.0    1,453.632639905  USD\tmillions      Central\tBank\tof\tKenya
# 8  2024.0    5,004.769090469  USD\tmillions      Central\tBank\tof\tKenya
# 9  2020.0         30.3408085  USD\tmillions              Bank\tAl-Maghrib
# Shape: (90, 6)
#
# Table 2 - First 10 rows of raw data:
#                                                    0                    1  \
# 0  Indicator:\tB\t-\tCentral\tBank\tremittance\ti...                  NaN
# 1                                   Sending\tcountry  Receive\tcou.. Date
# 2                                      South\tAfrica       Ethiopia\n2020
# 3                                                NaN          Kenya\n2024
# 4                                                NaN        Senegal\n2021
# 5                                                NaN         Uganda\n2022
# 6                                       South\tSudan       Ethiopia\n2020
# 7                                                NaN          Kenya\n2024
# 8                                                NaN         Uganda\n2022
# 9                                              Spain        Morocco\n2020
#
#                   2              3                             4
# 0               NaN            NaN                           NaN
# 1             Value  USD\tmillions                        Source
# 2       67.93372415  USD\tmillions  National\tBank\tof\tEthiopia
# 3  24,095.095706679  USD\tmillions      Central\tBank\tof\tKenya
# 4      14.579840557  USD\tmillions                         BCEAO
# 5              28.7  USD\tmillions              Bank\tof\tUganda
# 6       11.33937986  USD\tmillions  National\tBank\tof\tEthiopia
# 7   5,789.706224355  USD\tmillions      Central\tBank\tof\tKenya
# 8             113.3  USD\tmillions              Bank\tof\tUganda
# 9       705.7301285  USD\tmillions              Bank\tAl-Maghrib
# Shape: (43, 5)
#
# 🧹 CLEANED DATA (After processing):
# ----------------------------------------
# Table 1 - First 10 rows of cleaned data:
#            0         1       2                  3              4  \
# 0    Algeria   Senegal  2021.0        0.183414825  USD\tmillions
# 1  Australia  Ethiopia  2020.0        13.59617511  USD\tmillions
# 2        NaN     Kenya  2024.0  184,497.099695719  USD\tmillions
# 3        NaN    Uganda  2022.0                 22  USD\tmillions
# 4    Austria     Kenya  2024.0   13,169.065145833  USD\tmillions
# 5    Bahamas     Kenya  2024.0    1,453.632639905  USD\tmillions
# 6    Bahrain     Kenya  2024.0    5,004.769090469  USD\tmillions
# 7        NaN   Morocco  2020.0         30.3408085  USD\tmillions
# 8    Belgium     Kenya  2024.0   22,844.654997935  USD\tmillions
# 9        NaN   Morocco  2020.0         387.629403  USD\tmillions
#
#                               5
# 0                         BCEAO
# 1  National\tBank\tof\tEthiopia
# 2      Central\tBank\tof\tKenya
# 3              Bank\tof\tUganda
# 4      Central\tBank\tof\tKenya
# 5      Central\tBank\tof\tKenya
# 6      Central\tBank\tof\tKenya
# 7              Bank\tAl-Maghrib
# 8      Central\tBank\tof\tKenya
# 9              Bank\tAl-Maghrib
# Shape: (88, 6)
#
# Table 2 - First 10 rows of cleaned data:
#                0               1                 2              3  \
# 0  South\tAfrica  Ethiopia\n2020       67.93372415  USD\tmillions
# 1            NaN     Kenya\n2024  24,095.095706679  USD\tmillions
# 2            NaN   Senegal\n2021      14.579840557  USD\tmillions
# 3            NaN    Uganda\n2022              28.7  USD\tmillions
# 4   South\tSudan  Ethiopia\n2020       11.33937986  USD\tmillions
# 5            NaN     Kenya\n2024   5,789.706224355  USD\tmillions
# 6            NaN    Uganda\n2022             113.3  USD\tmillions
# 7          Spain   Morocco\n2020       705.7301285  USD\tmillions
# 8            NaN   Senegal\n2021     682.891794356  USD\tmillions
# 9          Sudan  Ethiopia\n2020        1.89005089  USD\tmillions
#
#                               4
# 0  National\tBank\tof\tEthiopia
# 1      Central\tBank\tof\tKenya
# 2                         BCEAO
# 3              Bank\tof\tUganda
# 4  National\tBank\tof\tEthiopia
# 5      Central\tBank\tof\tKenya
# 6              Bank\tof\tUganda
# 7              Bank\tAl-Maghrib
# 8                         BCEAO
# 9  National\tBank\tof\tEthiopia
# Shape: (41, 5)
#
# 🔍 KEY DIFFERENCES:
# ----------------------------------------
# 1. HEADER ROWS: Uncleaned data contains PDF metadata and headers
#    - Raw data includes indicator descriptions, column headers
#    - Cleaned data starts from actual data rows
#
# 2. EMPTY ROWS: Uncleaned data may have empty/null rows
#    - Raw data preserves PDF structure including spaces
#    - Cleaned data removes empty rows
#
# 3. DATA STRUCTURE: Cleaned data is more analysis-ready
#    - Raw data preserves original PDF formatting
#    - Cleaned data has consistent column structure
#
# 4. SIZE DIFFERENCE:
#    - Table 1: 90 rows → 88 rows
#    - Table 2: 43 rows → 41 rows
